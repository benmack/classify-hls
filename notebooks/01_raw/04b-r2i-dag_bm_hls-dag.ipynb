# %% [markdown]
# # HLS - DAG
#
#
# **TODO: Execute when ready.**

# %% [markdown]
# ## DAG graph

# %%
from IPython.display import SVG

SVG(filename="dag-graphs/dag_r2i_hls-prepare-l2-single-layer-files.svg")

# %% [markdown]
# ## Workflow

# %%
# %%bash
#
# # cat ../../Snakefile_hls-prepare-l2-single-layer-files
